# %%
from httpcore import request

print("hello world")
# Out:
# hello world

# %%
# %pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp39-cp39-macosx_10_9_universal2.whl.metadata (37 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hesandaliyanage/Documents/GitHub/hess-get-fit/analytics-microservice/.venv/lib/python3.9/site-packages (from requests) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hesandaliyanage/Documents/GitHub/hess-get-fit/analytics-microservice/.venv/lib/python3.9/site-packages (from requests) (2026.1.4)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp39-cp39-macosx_10_9_universal2.whl (209 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Installing collected packages: urllib3, charset_normalizer, requests
# Successfully installed charset_normalizer-3.4.4 requests-2.32.5 urllib3-2.6.3
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: /Users/hesandaliyanage/Documents/GitHub/hess-get-fit/analytics-microservice/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
endpoint = "/testservice"
base_url = "http://127.0.0.1:8000"
endpoint = f"{base_url}{endpoint}"
endpoint
# Out:
# 'http://127.0.0.1:8000/testservice'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True
